# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
from urllib.parse import quote
from tqdm import tqdm
import warnings
import pandas as pd
import numpy as np
warnings.filterwarnings('ignore')

# %%
# url 가져오기 
url = 'https://sports.news.naver.com/index'
driver = webdriver.Chrome('C:/Users/YONSAI/Downloads/chromedriver.exe')
driver.get(url)
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
titles = soup.select('div.text_area > strong')
titles
# Out:
# [<strong class="title">150km 머신공 500개씩 봤지만… '잠실 빅보이' 2군 첫 출전 3타수 무안타 1볼넷</strong>,
#  <strong class="title">홈런 1위 1루수 vs 홀드 5위 좌완. 차명석 단장님, 2년 만에 윈-윈 트레이드 되나요</strong>,
#  <strong class="title"> 몰아치던 토트넘, 갑작스러운 손흥민 교체…이유는?</strong>,
#  <strong class="title">흔들린 '투수 오타니', 타석서 맹활약해 '시즌 4승째'</strong>,
#  <strong class="title">'포체티노는 계획이 다 있구나! '…첼시 '최대 문제점' 해결 위해, EPL 득점 3위 노려</strong>,
#  <strong class="title">브라운+테이텀 62점, 보스턴 PO 2R 진출, 필라델피아와 맞대결, 서부 두 자리만 남았다</strong>,
#  <strong class="title">하은주, 이번엔 타임슬립설 상상 이상의 사기캐였던 언니들.. 여농 레전드 정선민 감독편 [경기의재구성]30화 l KBS방송</strong>,
#  <strong class="title">'홈에서 1루까지 4.08초' 배지환 빠른 발에 정신 못 차린 신더가드</strong>,
#  <strong class="title">이강인 아틀레티코전 4인 돌파 드리블 '아르헨 월드컵 풀백 농락' (스페인 현지 극찬)</strong>,
#  <strong class="title">LG 대형 FA 영입?/ 가스공사, 유도훈 감독과 결별?/ KCC 빅3 시너지는/ KT 양홍석 가치/DB개편</strong>,
#  <strong class="title">김하성 2안타 2도루, 배지환 3안타 3도루</strong>,
#  <strong class="title">불꽃 카리스마 명보 ｜울산현대 홍명보 감독</strong>,
#  <strong class="title">'국가대표에게 직접 배운다' 김병철- 김승현, 농구 꿈나무 밀착 레슨 현장</strong>,
#  <strong class="title">봉춤? 폴댄스? 이제는 폴스포츠! 2023 한국 폴스포츠 선수권 대회 그 현장 속으로</strong>,
#  <strong class="title">이게 돼야 진심 100타에서 벗어나요!</strong>,
#  <strong class="title">꽃미남 축구선수 계보 (f.눈호강 주의)</strong>,
#  <strong class="title">[Winterview] '기사단의 퍼펙트한 연승 질주' SK, 최부경-허일영 인터뷰</strong>,
#  <strong class="title">KPGA vs KLPGA 골프치다 프로 남매에게 무슨일이?</strong>,
#  <strong class="title">울산현대, 인천 원정에서 "잘 있어요~~~"</strong>,
#  <strong class="title">[이시우 레슨] ＜드라이버＞다운스윙 시 하체 회전하고 상체는 허리 지점에서 멈추기</strong>,
#  <strong class="title">한이 맺힌 두 MVP "득점왕 경쟁?!"</strong>,
#  <strong class="title">'수비수 4명 돌파' 경이로운 이강인의 탈압박!! 라리가 최고의 드리블러가 되어가는 이강인</strong>,
#  <strong class="title">[골프 레슨] 아이언샷 뒤땅과 탑볼은 같은 이유 때문에 발생한다는 것을 알고 계신가요?</strong>,
#  <strong class="title">이강인 70미터 단독 돌파 원더골 '평점 9점 공식 MVP' (헤타페전 역전승)</strong>,
#  <strong class="title">'4무 4패' 강원FC가 시즌 첫 승을 거둘 수 있었던 이유</strong>,
#  <strong class="title">턱걸이 제발 ‘이렇게’ 하세요! 팔로 당기지말고 등으로 당기세요!</strong>,
#  <strong class="title">"정식 감독 준비됐다" 메이슨 대행 손흥민 선발 제외?! (맨유전 기자회견 풀버전 해설)</strong>,
#  <strong class="title">네? 죽은 엉덩이도 살려낸다구요?? ‘달인의 힙업운동 비법 공개’ [엉덩이의 달인]</strong>,
#  <strong class="title">K리그 감독들 과거 사진 대방출 (f.앙드레 익수)</strong>,
#  <strong class="title">[공태현 레슨] ＜웨지＞ 팔을 접었다 펴는 느낌 활용하기</strong>,
#  <strong class="title">[4K 직캠] 조코비치 잡았던 정현..31개월 만에 단식 기강 잡으러 옴ㅣ2023 서울오픈챌린저</strong>,
#  <strong class="title">'3안타 3도루 3득점' 배지환 벌써 시즌 10호 도루!</strong>,
#  <strong class="title">피츠버그 8연승 저지한 다저스...배지환 2안타 2도루</strong>,
#  <strong class="title">김병철-김승현, 슛 대결·시합까지 '이것이 국대 클래스'</strong>,
#  <strong class="title">‘학폭 때문에...’ 김유성의 10분과 '식은땀', 모든 학생 선수들이 보고 느껴야 [김동영의 시선]</strong>,
#  <strong class="title">‘프레디-최승빈’ 보유한 건국대, 김도연이 느끼는 그 장점은?</strong>,
#  <strong class="title">세계 358위 요한손 LA 챔피언십 첫날 깜짝선두… 양희영, 유해란 공동 7위 출발</strong>,
#  <strong class="title">“손흥민은 토트넘의 구명보트”</strong>,
#  <strong class="title">'박지수·김단비 포함' 여자 농구 대표팀, 아시아컵 대비 최종 12인 선발</strong>,
#  <strong class="title">'직업윤리, 팬들의 사랑 그리고 폭발력'…토트넘에서 절대 팔 수 없는 '그 이름'</strong>,
#  <strong class="title">'괴물' 김민재, 6월 A매치 못뛰나 '6월 군사훈련 예정'</strong>,
#  <strong class="title">"이케멘?" 녹아내린 日리베로, 임성진과 미남 듀오 될까…사령탑은 '물음표' [SC포커스]</strong>,
#  <strong class="title">“눈도 깜빡이지 말라”는 LIV의 자신감 [LIV 싱가포르]</strong>,
#  <strong class="title">다 바꾸고 자신감 되찾은 박결, 이틀째 선두권</strong>,
#  <strong class="title">브라운+테이텀 62점, 보스턴 PO 2R 진출, 필라델피아와 맞대결, 서부 두 자리만 남았다</strong>,
#  <strong class="title">기적같은 역전 만루포에 달아오른 사자군단, 오재일 뜨겁게 안아준 강민호와 박한이 코치</strong>]

# %%
title = titles[0]
title
# Out:
# <strong class="title">150km 머신공 500개씩 봤지만… '잠실 빅보이' 2군 첫 출전 3타수 무안타 1볼넷</strong>

# %%
title.get_text().strip()
# Out:
# "150km 머신공 500개씩 봤지만… '잠실 빅보이' 2군 첫 출전 3타수 무안타 1볼넷"

# %%
페이지
다음x 
a 태그가 5개 면 6개
다음1
a 5 16
다음2
a 5 25

# %%
lines = []
titles = soup.select('div.text_area > strong')
title = titles[0]
for title in titles:
    lines.append(title.get_text().strip())

# %%
# a_list = []
# titles = soup.select('div.text_area > strong')
# title = titles[0]
# for title in titles:
#     # ps = title.select('div.text_area > strong')
#     paragraph = ''
#     for p in titles:
#         text = p.get_text()
#         paragraph += text + '\n'
#     a_list.append(paragraph)

# %%
# aa_list = []
# titles = soup.select('div.text_area > strong')
# title = titles[0]
# paragraph = ''
# for title in titles:
#     text = title.get_text().strip()
#     paragraph += text + '\n'
# aa_list.append(paragraph)

# %%
with open('data/스포츠뉴스.txt', 'w', encoding='utf-8') as f:
    for line in lines:
        f.write(line + '\n')

# %%
len(lines), lines
# Out:
# (46,
#  ['논란 배제+신예 중심+아마 포함, AG 대표팀 확 바뀐다',
#   '이강인 EPL 아닌 \'라리가 잔류\' 가능성 "ATM 시메오네 감독 영입 승인, 매우 단호"',
#   "'타자 오타니'가 '투수 오타니'를 구했다",
#   "타선아 힘내라, 우리가 버틸게… KIA 마운드 분전 '리그 1위' LG 상대로도 통할까",
#   '"맨시티서 행복하지 않다" 올여름 \'이적 추진\', 연봉 삭감도 흔쾌히',
#   "김하성 2경기 연속 멀티 출루 '부진 탈출'…팀은 컵스에 패",
#   '울산현대, 인천 원정에서 "잘 있어요~~~"',
#   '[공태현 레슨] ＜웨지＞ 팔을 접었다 펴는 느낌 활용하기',
#   "'굴욕적인 경기' 맨시티에게 처참하게 패배한 아스날, 전술천재 과르디올라",
#   '[이시우 레슨] ＜드라이버＞다운스윙 시 하체 회전하고 상체는 허리 지점에서 멈추기',
#   "이강인 아틀레티코전 4인 돌파 드리블 '아르헨 월드컵 풀백 농락' (스페인 현지 극찬)",
#   '피츠버그 8연승 저지한 다저스...배지환 2안타 2도루',
#   "[Winterview] '기사단의 퍼펙트한 연승 질주' SK, 최부경-허일영 인터뷰",
#   '"정식 감독 준비됐다" 메이슨 대행 손흥민 선발 제외?! (맨유전 기자회견 풀버전 해설)',
#   '네? 죽은 엉덩이도 살려낸다구요?? ‘달인의 힙업운동 비법 공개’ [엉덩이의 달인]',
#   'K리그 감독들 과거 사진 대방출 (f.앙드레 익수)',
#   '누워서 하는 복근 운동(층간소음 X) 단 15분 선명한 복근 완성하기',
#   '[두잇골프] 하체턴 너무어렵죠? 이 기초 동작을 익히지 않으면 계속 어렵습니다.',
#   "'4무 4패' 강원FC가 시즌 첫 승을 거둘 수 있었던 이유",
#   '[4K 직캠] 조코비치 잡았던 정현..31개월 만에 단식 기강 잡으러 옴ㅣ2023 서울오픈챌린저',
#   '턱걸이 제발 ‘이렇게’ 하세요! 팔로 당기지말고 등으로 당기세요!',
#   '이게 돼야 진심 100타에서 벗어나요!',
#   "'홈에서 1루까지 4.08초' 배지환 빠른 발에 정신 못 차린 신더가드",
#   '꽃미남 축구선수 계보 (f.눈호강 주의)',
#   '봉춤? 폴댄스? 이제는 폴스포츠! 2023 한국 폴스포츠 선수권 대회 그 현장 속으로',
#   'LG 대형 FA 영입?/ 가스공사, 유도훈 감독과 결별?/ KCC 빅3 시너지는/ KT 양홍석 가치/DB개편',
#   'KPGA vs KLPGA 골프치다 프로 남매에게 무슨일이?',
#   "'3안타 3도루 3득점' 배지환 벌써 시즌 10호 도루!",
#   '김하성 2안타 2도루, 배지환 3안타 3도루',
#   '불꽃 카리스마 명보 ｜울산현대 홍명보 감독',
#   '"KIM!!" 김하성, 꼬마 팬들 외침에 팬 서비스는 확실하게',
#   '하은주, 이번엔 타임슬립설 상상 이상의 사기캐였던 언니들.. 여농 레전드 정선민 감독편 [경기의재구성]30화 l KBS방송',
#   '[허석프로] 드라이버 레슨은 이것만 따라하세요',
#   "'국가대표에게 직접 배운다' 김병철- 김승현, 농구 꿈나무 밀착 레슨 현장",
#   "19살 루키 '139㎞ 직구' 통하는 이유 있었다 '무브먼트 전체 4위, 회전수는 3위'",
#   '‘4순위 지명’에도, OK금융그룹이 미소 지은 이유 [SS현장]',
#   '고우석 연투 봉인, 드디어 해제됐다 “당장 오늘도 쓸 수 있다”',
#   '\'대만족\' 페루 감독, "한국은 포르투갈을 이긴 팀, 남미 팀과 비슷해"',
#   "투헬 왜 잘랐나...경질 전 '63경기' 11패→경질 후 '26경기' 11패",
#   '‘전북 골문 저격+K리그 데뷔골’ 대전 수비수 안톤, 9라운드 MVP 선정',
#   'K리그1도 접수한 이진현 "더브라위너처럼 알고도 못 막게 할 겁니다" [서호정]',
#   '\'룰러\' 박재혁, MSI LPL 영상 등장..."왕호야... 왜 나한테 펜타 안 줬어?"',
#   "김하성 2경기 연속 멀티 출루 '부진 탈출'...팀은 컵스에 패",
#   "박병호와 작별 후 1년, 키움 새 1루수는 돌고돌아 '베테랑' 이원석",
#   '양키스전에 마가 꼈나…큰 부상 피했지만, 美日 156승 투수 또 이탈 전망',
#   '김민재 ‘나폴리+마라도나 역사’ 탑승하나…33년만 스쿠데토 정조준'])

# %%
import re, nltk
from konlpy.tag import Okt 
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus']=False

# %%
with open('data/스포츠뉴스.txt') as f:
    text = f.read()

# %%
okt = Okt()
tokens = okt.nouns(text) # 문장에서 명사 추출 (그런데 꼭 그렇게 추출되지만은 않다.)
tokens[:10]
# Out:
# ['논란', '배제', '신예', '중심', '아마', '포함', '대표팀', '확', '이강인', '라리가']

# %%
stoptext = """ 
    감독 경기 패 위 전 수 이유 현장 입 오타 동 이 한국 왜
"""
stop_words = stoptext.split()
new_tokens = [word for word in sports if word not in stop_words]
new_tokens[:10]
sports = nltk.Text(new_tokens, name='스포츠뉴스')
plt.figure(figsize=(12,6))
sports.plot(50);

# %%
data = sports.vocab().most_common(5)
data
# Out:
# [('도루', 5), ('리그', 4), ('김하성', 4), ('팀', 4), ('레슨', 4)]

# %%
wc = WordCloud(
    background_color='white',
    random_state=2023,
    font_path='c/windows/Fonts/malgun.ttf'
).generate_from_frequencies(dict(sports.vocab().most_common(300)))

# plt.figure(figsize=(10,6))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off');

# %%
with open('data/여친선물.txt') as f:
    text1 = f.read()

# %%
present = okt.nouns(text1)
present[:10]
# Out:
# ['혹시', '여친', '생리통', '여친', '선물', '복부', '열기', '저', '생리통', '이번']

# %%
stoptext = """ 
    감독 경기 패 위 전 수 이유 현장 입 오타 동 이 한국 왜
"""
stop_words = stoptext.split()
new_tokens = [word for word in present if word not in stop_words]
new_tokens[:10]
present = nltk.Text(new_tokens, name='여친선물')
plt.figure(figsize=(12,6))
present.plot(50);

# %%
wc = WordCloud(
    background_color='white',
    random_state=2023,
    font_path='c/windows/Fonts/malgun.ttf'
).generate_from_frequencies(dict(present.vocab().most_common(300)))

# plt.figure(figsize=(10,6))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off');
