# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
import requests, folium
from urllib.parse import quote
from bs4 import BeautifulSoup

# %%
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')

url = 'https://www.ggpolice.go.kr/main/html.do?menu=HC44'
driver = webdriver.Chrome('C:/Users/YONSAI/Downloads/chromedriver.exe') # chromedriver 위치
# driver = webdriver.Chrome(r'C:\Users\user\Downloads\chromedriver.exe')  # 집에서
driver.get(url)

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')
lis = soup.select('li.road')
len(lis)
# Out:
# 31

# %%
li = lis[0]
li
# Out:
# <li class="road selected">
# <a href="https://www.ggpolice.go.kr/swjb/html.do?menu=HC24">수원중부서</a>
# </li>

# %%
href = li.select_one('a')['href']
href
# Out:
# 'https://www.ggpolice.go.kr/swjb/html.do?menu=HC24'

# %%
# href 가져와서 서브수프만듦
res = requests.get(href)
sub_soup = BeautifulSoup(res.text)

# %%
len(sub_soup.select('li'))
# Out:
# 128

# %%
# 서브리스트만듦
sub_lis = sub_soup.select('.basic_list7 > li')
sub_lis
# Out:
# [<li>기관명 : 수원중부경찰서</li>,
#  <li>도로명 주소 : 경기도 수원시 장안구 정자천로 199 (우)16335</li>,
#  <li>대표전화 : 경찰민원 콜센터 182</li>]

# %%
police = sub_lis[0].get_text().split(':')[1]
police
# Out:
# ' 수원중부경찰서'

# %%
sub_lis[1]
# Out:
# <li>도로명 주소 : 경기도 수원시 장안구 정자천로 199 (우)16335</li>

# %%
addr = sub_lis[1].get_text().split(':')[1].split('(')[0].strip()
addr
# Out:
# '경기도 수원시 장안구 정자천로 199'

# %%
addr_dict = {}
for li in sub_lis[1]:
    item = li.get_text().split(':')
    addr_dict[item[0].strip()] = item[1].split('(')[0].strip()
addr_dict
# Out:
# {'도로명 주소': '경기도 수원시 장안구 정자천로 199'}

# %%
    # for li in sub_lis[1]:
    #     item = li.get_text().split(':')
    #     addr_dict[item[0].strip()] = item[1].split('(')[0].strip()

# %%
# # try,except로 에러 인덱스를 확인해보기0.
# url = 'https://www.ggpolice.go.kr/main/html.do?menu=HC44'
# soup = BeautifulSoup(driver.page_source)
# lines = []
# lis = soup.select('li.road')
# for index, li in enumerate(lis): # 에러 인덱스를 보기위해 index인자 만들고 enumerate해줌
#     driver.get(url)
#     href = li.select_one('a')['href']
#     try:    
#         res = requests.get(href)
#         sub_soup = BeautifulSoup(res.text)
#         sub_lis = sub_soup.select('.basic_list7 > li') # 
#     # if len(sub_lis) == 0 : # list의 개수가없는것은 주소랑 없는 예외..수원남부경찰서
#     #     continue # 위로다시올라감
#         police = sub_lis[0].get_text().split(':')[1]
#         addr = sub_lis[1].get_text().split(':')[1].split('(')[0].strip()

#         lines.append({'경찰서이름':police, '주소':addr})
#     except:
#         print(index) # 에러인덱스확인
#         continue    
# driver.close()

# %%
# 에러인덱스 확인후 조건문 만들어서 해결
url = 'https://www.ggpolice.go.kr/main/html.do?menu=HC44'
soup = BeautifulSoup(driver.page_source)
lines = []
lis = soup.select('li.road')
for li in lis:
    driver.get(url)
    href = li.select_one('a')['href']
    
    res = requests.get(href)
    sub_soup = BeautifulSoup(res.text)
    sub_lis = sub_soup.select('.basic_list7 > li') # 
    if len(sub_lis) == 0 : # list의 개수가없는것은 주소랑 없는 예외..수원남부경찰서
        continue # 위로다시올라감
    police = sub_lis[0].get_text().split(':')[1]
    addr = sub_lis[1].get_text().split(':')[1].split('(')[0].strip()

    lines.append({'경찰서이름':police, '주소':addr})
driver.close()

# %%
# 에러인덱스 확인후 조건문 만들어서 해결
# for문 안에는 서브스프만 있으면되고
# for문 밖에 메인스프가 있어야함
lines = []
lis = soup.select('li.road')
for li in lis:
    href = li.select_one('a')['href']

    res = requests.get(href)
    sub_soup = BeautifulSoup(res.text)
    sub_lis = sub_soup.select('.basic_list7 > li') # 
    if len(sub_lis) == 0 : # list의 개수가없는것은 주소랑 없는 예외..수원남부경찰서
        continue # 위로다시올라감
    police = sub_lis[0].get_text().split(':')[1]
    addr = sub_lis[1].get_text().split(':')[1].split('(')[0].strip()

    lines.append({'경찰서이름':police, '주소':addr})
driver.close()

# %%
# 에러해결방안을 못찾을경우
# 정확한 원인을 찾지 못하는 경우, just skip
# 기냥..ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# try하고 except에서 continue해라 / indentation잘 맞춰야함

# %%
df = pd.DataFrame(lines)

# %%
df
# Out:
#        경찰서이름                       주소
# 0    수원중부경찰서     경기도 수원시 장안구 정자천로 199
# 1    수원남부경찰서        경기 수원시 영통구 매봉로 52
# 2    수원서부경찰서      경기 수원시 권선구 서부로 1673
# 3    안양동안경찰서  경기도 안양시 동안구 동안로159번길 43
# 4    안양만안경찰서       경기도 안양시 만안구 냉천로 63
# 5      과천경찰서            경기 과천시 통영로 20
# 6    성남수정경찰서     경기 성남시 수정구 성남대로 1259
# 7    성남중원경찰서     경기 성남시 중원구 금빛로2번길 10
# 8      분당경찰서      경기 성남시 분당구 정자일로 165
# 9    부천소사경찰서          경기 부천시  부광로 214
# 10   부천원미경찰서      경기 부천시 조마루로311번길 84
# 11   부천오정경찰서           경기 부천시 소사로 631
# 12     광명경찰서            경기 광명시 디지털로 5
# 13   안산단원경찰서      경기도 안산시 단원구 화랑로 373
# 14   안산상록경찰서      경기 안산시 상록구 차돌배기로 10
# 15     시흥경찰서          경기 시흥시 황고개로 513
# 16     평택경찰서           경기도 평택시 중앙로 67
# 17     오산경찰서          경기 오산시 동부대로 596
# 18   화성동탄경찰서      경기도 화성시 동탄대로 13길 70
# 19   화성서부경찰서       경기 화성시 남양읍 남양로 570
# 20   용인동부경찰서       경기 용인시 처인구 금학로 143
# 21   수원남부경찰서        경기 수원시 영통구 매봉로 52
# 22     광주경찰서          경기 광주시 포돌이로 135
# 23     이천경찰서            경기 이천시 부악로 32
# 24     안성경찰서          경기 안성시 알미산로 140
# 25     여주경찰서            경기 여주시 세종로 50
# 26     양평경찰서       경기도 양평군 옥천면 고읍로 88
# 27     의왕경찰서            경기 의왕시 오봉로 10
# 28     하남경찰서            경기 하남시 검단로 27

# %%
# 수원남부경찰서 중복제거 2,21
# df1 = df.drop_duplicates('경찰서이름',inplace=True).reset_index(drop=True)
# df1

# %%
# 중복 여부 확인
len(df.경찰서이름.unique())
# Out:
# 28

# %%
# 29개의 결과가 나왔는데 len은 28이니 중복이 확인됨
df.drop_duplicates(subset='경찰서이름', inplace=True)
df.shape
# Out:
# (28, 2)

# %%
df
# Out:
#        경찰서이름                       주소
# 0    수원중부경찰서     경기도 수원시 장안구 정자천로 199
# 1    수원남부경찰서        경기 수원시 영통구 매봉로 52
# 2    수원서부경찰서      경기 수원시 권선구 서부로 1673
# 3    안양동안경찰서  경기도 안양시 동안구 동안로159번길 43
# 4    안양만안경찰서       경기도 안양시 만안구 냉천로 63
# 5      과천경찰서            경기 과천시 통영로 20
# 6    성남수정경찰서     경기 성남시 수정구 성남대로 1259
# 7    성남중원경찰서     경기 성남시 중원구 금빛로2번길 10
# 8      분당경찰서      경기 성남시 분당구 정자일로 165
# 9    부천소사경찰서          경기 부천시  부광로 214
# 10   부천원미경찰서      경기 부천시 조마루로311번길 84
# 11   부천오정경찰서           경기 부천시 소사로 631
# 12     광명경찰서            경기 광명시 디지털로 5
# 13   안산단원경찰서      경기도 안산시 단원구 화랑로 373
# 14   안산상록경찰서      경기 안산시 상록구 차돌배기로 10
# 15     시흥경찰서          경기 시흥시 황고개로 513
# 16     평택경찰서           경기도 평택시 중앙로 67
# 17     오산경찰서          경기 오산시 동부대로 596
# 18   화성동탄경찰서      경기도 화성시 동탄대로 13길 70
# 19   화성서부경찰서       경기 화성시 남양읍 남양로 570
# 20   용인동부경찰서       경기 용인시 처인구 금학로 143
# 22     광주경찰서          경기 광주시 포돌이로 135
# 23     이천경찰서            경기 이천시 부악로 32
# 24     안성경찰서          경기 안성시 알미산로 140
# 25     여주경찰서            경기 여주시 세종로 50
# 26     양평경찰서       경기도 양평군 옥천면 고읍로 88
# 27     의왕경찰서            경기 의왕시 오봉로 10
# 28     하남경찰서            경기 하남시 검단로 27

# %%
df.to_csv('data/경기남부경찰서.csv' ,index=False)

# %% [markdown]
# - 카카오 api

# %%
with open('../04.지도시각화/data/kakaoapikey.txt') as f:
    kakao_key = f.read()

# %%
base_url = 'https://dapi.kakao.com/v2/local/search/address.json' # 카카오 Request get
addr = '경기도 수원시 영통구 월드컵로 199 (원천동)'
url = f'{base_url}?query={quote(addr)}'
url
# Out:
# 'https://dapi.kakao.com/v2/local/search/address.json?query=%EA%B2%BD%EA%B8%B0%EB%8F%84%20%EC%88%98%EC%9B%90%EC%8B%9C%20%EC%98%81%ED%86%B5%EA%B5%AC%20%EC%9B%94%EB%93%9C%EC%BB%B5%EB%A1%9C%20199%20%28%EC%9B%90%EC%B2%9C%EB%8F%99%29'

# %%
header = {'Authorization': f'KakaoAK {kakao_key}'}

# %%
result = requests.get(url, headers=header).json() 
result
# Out:
# {'documents': [{'address': {'address_name': '경기 수원시 영통구 원천동 13-4',
#     'b_code': '4111710200',
#     'h_code': '4111755000',
#     'main_address_no': '13',
#     'mountain_yn': 'N',
#     'region_1depth_name': '경기',
#     'region_2depth_name': '수원시 영통구',
#     'region_3depth_h_name': '원천동',
#     'region_3depth_name': '원천동',
#     'sub_address_no': '4',
#     'x': '127.044142224462',
#     'y': '37.279204703544'},
#    'address_name': '경기 수원시 영통구 월드컵로 199',
#    'address_type': 'ROAD_ADDR',
#    'road_address': {'address_name': '경기 수원시 영통구 월드컵로 199',
#     'building_name': '아주대학교어학교육원',
#     'main_building_no': '199',
#     'region_1depth_name': '경기',
#     'region_2depth_name': '수원시 영통구',
#     'region_3depth_name': '원천동',
#     'road_name': '월드컵로',
#     'sub_building_no': '',
#     'underground_yn': 'N',
#     'x': '127.044142224462',
#     'y': '37.279204703544',
#     'zone_no': '16502'},
#    'x': '127.044142224462',
#    'y': '37.279204703544'}],
#  'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}

# %%
lat = float(result['documents'][0]['y']) # 경도 문자열로나와서 float
lng = float(result['documents'][0]['x']) # 위도
lat, lng
# Out:
# (37.279204703544, 127.044142224462)

# %%
# 반복문으로 위도,경도
lat_list, lng_list = [], []
for i in df.index:
    url = f'{base_url}?query={quote(df.주소[i])}' 
    result = requests.get(url, headers=header).json() 
    lat_list.append(float(result['documents'][0]['y']))
    lng_list.append(float(result['documents'][0]['x']))

# %%
# 위도,경도 열 만들기
df['위도'] = lat_list
df['경도'] = lng_list
df
# Out:
#        경찰서이름                       주소         위도          경도
# 0    수원중부경찰서     경기도 수원시 장안구 정자천로 199  37.297932  126.996317
# 1    수원남부경찰서        경기 수원시 영통구 매봉로 52  37.272104  127.054492
# 2    수원서부경찰서      경기 수원시 권선구 서부로 1673  37.258740  126.972264
# 3    안양동안경찰서  경기도 안양시 동안구 동안로159번길 43  37.391209  126.948866
# 4    안양만안경찰서       경기도 안양시 만안구 냉천로 63  37.387334  126.925974
# 5      과천경찰서            경기 과천시 통영로 20  37.429358  126.989987
# 6    성남수정경찰서     경기 성남시 수정구 성남대로 1259  37.442287  127.126662
# 7    성남중원경찰서     경기 성남시 중원구 금빛로2번길 10  37.442664  127.170371
# 8      분당경찰서      경기 성남시 분당구 정자일로 165  37.365305  127.105450
# 9    부천소사경찰서          경기 부천시  부광로 214  37.468723  126.824181
# 10   부천원미경찰서      경기 부천시 조마루로311번길 84  37.502463  126.777337
# 11   부천오정경찰서           경기 부천시 소사로 631  37.514495  126.800321
# 12     광명경찰서            경기 광명시 디지털로 5  37.474151  126.867804
# 13   안산단원경찰서      경기도 안산시 단원구 화랑로 373  37.321950  126.829564
# 14   안산상록경찰서      경기 안산시 상록구 차돌배기로 10  37.299196  126.845188
# 15     시흥경찰서          경기 시흥시 황고개로 513  37.376785  126.788109
# 16     평택경찰서           경기도 평택시 중앙로 67  36.994847  127.090958
# 17     오산경찰서          경기 오산시 동부대로 596  37.153637  127.082246
# 18   화성동탄경찰서      경기도 화성시 동탄대로 13길 70  37.185728  127.094115
# 19   화성서부경찰서       경기 화성시 남양읍 남양로 570  37.191338  126.822491
# 20   용인동부경찰서       경기 용인시 처인구 금학로 143  37.241558  127.180431
# 22     광주경찰서          경기 광주시 포돌이로 135  37.408822  127.239490
# 23     이천경찰서            경기 이천시 부악로 32  37.273597  127.434764
# 24     안성경찰서          경기 안성시 알미산로 140  37.000492  127.249659
# 25     여주경찰서            경기 여주시 세종로 50  37.293205  127.635529
# 26     양평경찰서       경기도 양평군 옥천면 고읍로 88  37.516925  127.454997
# 27     의왕경찰서            경기 의왕시 오봉로 10  37.345198  126.974049
# 28     하남경찰서            경기 하남시 검단로 27  37.522672  127.224643

# %%
map = folium.Map(location=[df.위도.mean(),df.경도.mean()], zoom_start=10)
for i in df.index:
    folium.Marker(
        location=[df.위도[i],df.경도[i]],
        popup=folium.Popup(df.주소[i],max_width=200),
        tooltip=df.경찰서이름[i],
        icon=folium.Icon(
        color ='blue',icon_color='white',
        icon='glyphicon glyphicon-pushpin', #glyphicon 아이콘 제공 사이트
        prefix='glyphicon'
    )
    ).add_to(map)
title_html ='<h3 align="center" style ="font-size:20px">경기남부경찰서 시각화</h3>'
map.get_root().html.add_child(folium.Element(title_html))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_48453b505c435f7183283efa85c026cf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style =&quot;font-size:20px&quot;&gt;경기남부경찰서 시각화&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_48453b505c435f7183283efa85c026cf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_48453b505c435f7183283efa85c026cf = L.map(
#                 &quot;map_48453b505c435f7183283efa85c026cf&quot;,
#                 {
#                     center: [37.334739850240645, 127.05379493717854],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_166d5e9cf7418e2367230f00feef8305 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_48453b505c435f7183283efa85c026cf);
#
#
#             var marker_0b459d8ff5363933e35aa41929a69b81 = L.marker(
#                 [37.2979319496338, 126.99631718583],
#                 {}
#             ).addTo(map_48453b505c435f7183283efa85c026cf);
#
#
#             var icon_1c2543ad82406cf651d9013588b00c22 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon glyphicon-pushpin&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0b459d8ff5363933e35aa41929a69b81.setIcon(icon_1c2543ad82406cf651d9013588b00c22);
#
#
#         var popup_74a454869ba083588a1ecd9126453bca = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_f28d3eacd68b81763377bcd3a713634e = $(`&lt;div id=&quot;html_f28d3eacd68b81763377bcd3a713634e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경기도 수원시 장안구 정자천로 199&lt;/div&gt;`)[0];
#                 popup_74a454869ba083588a1ecd9126453bca.setContent(html_f28d3eacd68b81763377bcd3a713634e);
#
#
#
#         marker_0b459d8ff5363933e35aa41929a69b81.bindPopup(popup_74a454869ba083588a1ecd9126453bca)
#         ;
#
#
#
#
#             marker_0b459d8ff5363933e35aa41929a69b81.bindTooltip(
#                 `&lt;div&gt;
#                       수원중부경찰서
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_fb841e98888352648fc5d0903a5c1206 = L.marker(
#                 [37.2721043390665, 127.054492051642],
#                 {}
#             ).addTo(map_48453b505c435f7183283efa85c026cf);
#
#
#             var icon_6d8e8ecf419c18977892903c6b408c6e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon glyphicon-pushpin&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fb841e98888352648fc5d0903a5c1206.setIcon(icon_6d8e8ecf419c18977892903c6b408c6e);
#
#
#         var popup_18cdd17daabed10501a450c82b505d06 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_618a565ceeb8f9a6b48aeafcbf9774c8 = $(`&lt;div id=&quot;html_618a565ceeb8f9a6b48aeafcbf9774c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경기 수원시 영통구 매봉로 52&lt;/div&gt;`)[0];
#                 popup_18cdd17daabed10501a450c82b505d06.setContent(html_618a565ceeb8f9a6b48aeafcbf9774c8);
#
#
#
#         marker_fb841e98888352648fc5d0903a5c1206.bindPopup(popup_18cdd17daabed10501a450c82b505d06)
#         ;
#
#
#
#
#             marker_fb841e98888352648fc5d0903a5c1206.bindTooltip(
#                 `&lt;div&gt;
#                       수원남부경찰서
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_96415033b5b1da099249e564f9166688 = L.marker(
#                 [37.2587398262097, 126.97226385575],
#                 {}
#             ).addTo(map_48453b505c435f7183283efa85c026cf);
#
#
#             var icon_cbec2a643078e1f2d5980fd2c13e06f8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon glyphicon-pushpin&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_96415033b5b1da099249e564f9166688.setIcon(icon_cbec2a643078e1f2d5980fd2c13e06f8);
#
#
#         var popup_4215310beb241f4a19a751c12b2ad411 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_71e96eb3afe178b777bb618544f6cc46 = $(`&lt;div id=&quot;html_71e96eb3afe178b777bb618544f6cc46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경기 수원시 권선구 서부로 1673&lt;/di
