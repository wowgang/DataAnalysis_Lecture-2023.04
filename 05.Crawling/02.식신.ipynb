# %% [markdown]
# ### 식신 - 장안문

# %%
import requests
from urllib.parse import quote
import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# ##### 1. 데이터 가져오기

# %%
# https://www.siksinhot.com/search?keywords=%EC%9E%A5%EC%95%88%EB%AC%B8
base_url = 'https://www.siksinhot.com/search'
url = f'{base_url}?keywords={quote("장안문")}'
result = requests.get(url)
html = result.text

# %%
result.text
# Out:
# '\n    <!DOCTYPE html>\n    <html lang="ko">\n      <head>\n        <title data-react-helmet="true">장안문 맛집 인기검색 순위</title>\n        <meta data-react-helmet="true" charset="utf-8"/><meta data-react-helmet="true" http-equiv="Content-Type" content="text/html; charset=utf-8"/><meta data-react-helmet="true" name="viewport" content="width=1024 width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no,user-scalable=0"/><meta data-react-helmet="true" name="format-detection" content="telephone=no"/><meta data-react-helmet="true" http-equiv="X-UA-Compatible" content="IE=edge"/><meta data-react-helmet="true" http-equiv="Pragma" content="no-cache"/><meta data-react-helmet="true" http-equiv="Expires" content="-1"/><meta data-react-helmet="true" property="me:feed:serviceId" content="web"/><meta data-react-helmet="true" property="fb:app_id" content="152382801468038"/><meta data-react-helmet="true" name="twitter:card" content="summary_large_image"/><meta data-react-helmet="true" name="twitter:site" content="@Siksin"/><meta data-react-helmet="true" name="twitter:creator" content="@Ahn"/><meta data-react-helmet="true" name="twitter:url" content="https://www.siksinhot.com/search?keywords=%EC%9E%A5%EC%95%88%EB%AC%B8"/><meta data-react-helmet="true" name="dable:item_id" content/><meta data-react-helmet="true" name="dable:title" content/><meta data-react-helmet="true" name="dable:author" content/><meta data-react-helmet="true" name="robots" content="max-image-preview:large"/><meta data-react-helmet="true" property="article:published_time" content="2022-09-23T14:30:25+09:00"/><meta data-react-helmet="true" property="og:article:author" content="안병익"/><meta data-react-helmet="true" property="og:site" content="https://www.siksinhot.com/search?keywords=%EC%9E%A5%EC%95%88%EB%AC%B8"/><meta data-react-helmet="true" property="og:type" content="website"/><meta data-react-helmet="true" property="og:url" content="https://www.siksinhot.com/search?keywords=%EC%9E%A5%EC%95%88%EB%AC%B8"/><meta data-react-helmet="true" property="al:ios:app_store_id" content="709111029"/><meta data-react-helmet="true" property="al:ios:app_name" content="Siksin"/><meta data-react-helmet="true" property="al:android:package" content="com.seeon.hotplace"/><meta data-react-helmet="true" property="al:android:app_name" content="Siksin"/><meta data-react-helmet="true" name="naver-site-verification" content="9286c46781d6c9f2dd096bb7be6c3c968ff19281"/><meta data-react-helmet="true" name="apple-mobile-web-app-capable" content="no"/><meta data-react-helmet="true" name="apple-mobile-web-app-status-bar-style" content="black-translucent"/><meta data-react-helmet="true" name="google-site-verification" content="2Hc5MorVr279IDxZ23nYQwKZOSkgh3YAgGU5PCP0Ank"/><meta data-react-helmet="true" name="google-translate-customization" content="a0e8194bbb4ac8e0-c88bee439f2a48c7-gfb69d183d0f3846f-11"/><meta data-react-helmet="true" name="keywords" content="돼지갈비,치킨/통닭,곱창/대창,삼계탕/백숙/찜닭,경양식/돈가스,회/횟집/참치,장어/꼼장어,설렁탕/곰탕/갈비탕,해물탕/해물요리,해장국/국밥/육개장"/><meta data-react-helmet="true" name="description" content="식신이 추천하는 장안문 맛집 인기검색 순위의 맛집 리스트결과는 52건 입니다. 장안문 맛집 인기검색 순위 가볼만한 곳의 메뉴, 위치, 연락처, 예약등의 매장정보를 식신이 소개합니다."/><meta data-react-helmet="true" name="subject" content="장안문 맛집 인기검색 순위"/><meta data-react-helmet="true" property="og:title" content="장안문 맛집 인기검색 순위"/><meta data-react-helmet="true" property="og:description" content="식신이 추천하는 장안문 맛집 인기검색 순위의 맛집 리스트결과는 52건 입니다. 장안문 맛집 인기검색 순위 가볼만한 곳의 메뉴, 위치, 연락처, 예약등의 매장정보를 식신이 소개합니다."/><meta data-react-helmet="true" name="twitter:title" content="장안문 맛집 인기검색 순위"/><meta data-react-helmet="true" name="twitter:description" content="식신이 추천하는 장안문 맛집 인기검색 순위의 맛집 리스트결과는 52건 입니다. 장안문 맛집 인기검색 순위 가볼만한 곳의 메뉴, 위치, 연락처, 예약등의 매장정보를 식신이 소개합니다."/><meta data-react-helmet="true" property="og:image" content="https://img.siksinhot.com/place/1374703567238427.png?w=560&amp;h=448&amp;c=Y"/>\n        <link data-react-helmet="true" rel="alternate" type="application/rss+xml" hre ...

# %%
html # 괜히 변수만들지말라....
# Out:
# '\n    <!DOCTYPE html>\n    <html lang="ko">\n      <head>\n        <title data-react-helmet="true">장안문 맛집 인기검색 순위</title>\n        <meta data-react-helmet="true" charset="utf-8"/><meta data-react-helmet="true" http-equiv="Content-Type" content="text/html; charset=utf-8"/><meta data-react-helmet="true" name="viewport" content="width=1024 width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no,user-scalable=0"/><meta data-react-helmet="true" name="format-detection" content="telephone=no"/><meta data-react-helmet="true" http-equiv="X-UA-Compatible" content="IE=edge"/><meta data-react-helmet="true" http-equiv="Pragma" content="no-cache"/><meta data-react-helmet="true" http-equiv="Expires" content="-1"/><meta data-react-helmet="true" property="me:feed:serviceId" content="web"/><meta data-react-helmet="true" property="fb:app_id" content="152382801468038"/><meta data-react-helmet="true" name="twitter:card" content="summary_large_image"/><meta data-react-helmet="true" name="twitter:site" content="@Siksin"/><meta data-react-helmet="true" name="twitter:creator" content="@Ahn"/><meta data-react-helmet="true" name="twitter:url" content="https://www.siksinhot.com/search?keywords=%EC%9E%A5%EC%95%88%EB%AC%B8"/><meta data-react-helmet="true" name="dable:item_id" content/><meta data-react-helmet="true" name="dable:title" content/><meta data-react-helmet="true" name="dable:author" content/><meta data-react-helmet="true" name="robots" content="max-image-preview:large"/><meta data-react-helmet="true" property="article:published_time" content="2022-09-23T14:30:25+09:00"/><meta data-react-helmet="true" property="og:article:author" content="안병익"/><meta data-react-helmet="true" property="og:site" content="https://www.siksinhot.com/search?keywords=%EC%9E%A5%EC%95%88%EB%AC%B8"/><meta data-react-helmet="true" property="og:type" content="website"/><meta data-react-helmet="true" property="og:url" content="https://www.siksinhot.com/search?keywords=%EC%9E%A5%EC%95%88%EB%AC%B8"/><meta data-react-helmet="true" property="al:ios:app_store_id" content="709111029"/><meta data-react-helmet="true" property="al:ios:app_name" content="Siksin"/><meta data-react-helmet="true" property="al:android:package" content="com.seeon.hotplace"/><meta data-react-helmet="true" property="al:android:app_name" content="Siksin"/><meta data-react-helmet="true" name="naver-site-verification" content="9286c46781d6c9f2dd096bb7be6c3c968ff19281"/><meta data-react-helmet="true" name="apple-mobile-web-app-capable" content="no"/><meta data-react-helmet="true" name="apple-mobile-web-app-status-bar-style" content="black-translucent"/><meta data-react-helmet="true" name="google-site-verification" content="2Hc5MorVr279IDxZ23nYQwKZOSkgh3YAgGU5PCP0Ank"/><meta data-react-helmet="true" name="google-translate-customization" content="a0e8194bbb4ac8e0-c88bee439f2a48c7-gfb69d183d0f3846f-11"/><meta data-react-helmet="true" name="keywords" content="돼지갈비,치킨/통닭,곱창/대창,삼계탕/백숙/찜닭,경양식/돈가스,회/횟집/참치,장어/꼼장어,설렁탕/곰탕/갈비탕,해물탕/해물요리,해장국/국밥/육개장"/><meta data-react-helmet="true" name="description" content="식신이 추천하는 장안문 맛집 인기검색 순위의 맛집 리스트결과는 52건 입니다. 장안문 맛집 인기검색 순위 가볼만한 곳의 메뉴, 위치, 연락처, 예약등의 매장정보를 식신이 소개합니다."/><meta data-react-helmet="true" name="subject" content="장안문 맛집 인기검색 순위"/><meta data-react-helmet="true" property="og:title" content="장안문 맛집 인기검색 순위"/><meta data-react-helmet="true" property="og:description" content="식신이 추천하는 장안문 맛집 인기검색 순위의 맛집 리스트결과는 52건 입니다. 장안문 맛집 인기검색 순위 가볼만한 곳의 메뉴, 위치, 연락처, 예약등의 매장정보를 식신이 소개합니다."/><meta data-react-helmet="true" name="twitter:title" content="장안문 맛집 인기검색 순위"/><meta data-react-helmet="true" name="twitter:description" content="식신이 추천하는 장안문 맛집 인기검색 순위의 맛집 리스트결과는 52건 입니다. 장안문 맛집 인기검색 순위 가볼만한 곳의 메뉴, 위치, 연락처, 예약등의 매장정보를 식신이 소개합니다."/><meta data-react-helmet="true" property="og:image" content="https://img.siksinhot.com/place/1374703567238427.png?w=560&amp;h=448&amp;c=Y"/>\n        <link data-react-helmet="true" rel="alternate" type="application/rss+xml" hre ...

# %%
soup = BeautifulSoup(result.text, 'html.parser')

# %% [markdown]
# ##### 2. 원하는데이터 찾기

# %%
lis = soup.find_all('li')
len(lis) # li 28개
# Out:
# 28

# %%
# 방법1
lis = soup.select_one('.localFood_list').find_all('li')
len(lis)
# Out:
# 20

# %%
# 방법2
lis = soup.select('.localFood_list > li')
len(lis)
# Out:
# 20

# %% [markdown]
# ##### 3. 하나를 선택해서 원하는 정보를 추출

# %%
li = lis[0]
img = li.find('img')['src']
img
# Out:
# 'https://img.siksinhot.com/place/1374703567238427.png?w=560&h=448&c=Y'

# %%
li
# Out:
# <li data-reactid="58"><figure data-reactid="59"><a data-reactid="60" href="https://www.siksinhot.com/P/317019" target="_blank"><img alt="장안문 , 서울특별시 중구 을지로3길 29" data-reactid="61" height="448" src="https://img.siksinhot.com/place/1374703567238427.png?w=560&amp;h=448&amp;c=Y" width="560"/></a></figure><figcaption data-reactid="62"><a class="textBox" data-reactid="63" href="https://www.siksinhot.com/P/317019" target="_blank"><h2 data-reactid="64">장안문</h2><span class="score" data-reactid="65">3.5</span></a><p class="cate" data-reactid="66"><a data-reactid="67" href="/search?keywords=시청">시청</a><!-- react-text: 68 --> / <!-- /react-text --><a data-reactid="69" href="/search?keywords=돼지갈비">돼지갈비</a></p><p class="counting" data-reactid="70"><img data-reactid="71" src="/static2/images/search/img/icon_view.png"/><span data-reactid="72">6015</span><img data-reactid="73" src="/static2/images/search/img/icon_bookmark.png"/><span data-reactid="74">9</span></p></figcaption></li>

# %%
# 업소명, 평점
li.select_one('.textBox').get_text()
# Out:
# '장안문3.5'

# %%
title = li.select_one('.textBox > h2').get_text()
score = li.select_one('.textBox > .score').get_text() # .score대신 span으로 해도됨
title, score
# Out:
# ('장안문', '3.5')

# %%
# 위치, 메뉴
atags = li.select('.cate > a')
atags
# Out:
# [<a data-reactid="67" href="/search?keywords=시청">시청</a>,
#  <a data-reactid="69" href="/search?keywords=돼지갈비">돼지갈비</a>]

# %%
location = atags[0].get_text()
menu = atags[1].get_text()
location, menu
# Out:
# ('시청', '돼지갈비')

# %% [markdown]
# ##### 4. 반복문을 사용하여 페이지에 있는 데이터 가져오기
#         - data를 가져온 다음 dataframe을 만들어야한다

# %%
line = []
for li in lis: # lis = soup.select('.localFood_list > li')
    img = li.find('img')['src']
    title = li.select_one('.textBox > h2').get_text()
    score = li.select_one('.textBox > .score').get_text()
    atags = li.select('.cate > a')
    location = atags[0].get_text()
    menu = atags[1].get_text()
    line.append({'img':img, 'title':title, 'score':score, 'location':location, 'menu':menu})

# %% [markdown]
# #### 5. 오류 발생 - 오류 해결

# %% [markdown]
# ##### 6. 오류 발생 - 오류해결

# %% [markdown]
# ##### 7. 데이터프레임 만들기

# %%
df = pd.DataFrame(line)
df
# Out:
#                                                   img         title score
# 0   https://img.siksinhot.com/place/13747035672384...           장안문   3.5  \
# 1   https://img.siksinhot.com/place/14576724616075...          장안통닭   4.2
# 2   https://img.siksinhot.com/place/14168290359781...          장안식당   3.7
# 3   https://img.siksinhot.com/place/13594443896888...        장안사 산장   3.5
# 4   https://img.siksinhot.com/place/16099132855466...           장안정   3.7
# 5   https://img.siksinhot.com/place/14640787918984...          장안횟집   3.5
# 6   https://img.siksinhot.com/place/15058927427102...        장안민물장어   4.3
# 7   https://img.siksinhot.com/place/14771561662543...         장안설렁탕   2.1
# 8   https://img.siksinhot.com/place/16287539479056...        장안삼계탕    3.1
# 9   https://img.siksinhot.com/place/14315472041328...         장안아구촌   3.0
# 10  https://img.siksinhot.com/place/15117206244024...         장안해물탕   2.8
# 11  https://img.siksinhot.com/place/16177638302981...  제주은희네해장국 장안점   평가중
# 12  https://img.siksinhot.com/place/16566625352599...     글로리식당 장안점   평가중
# 13  https://img.siksinhot.com/place/16757568568630...         장안라운지   평가중
# 14  https://img.siksinhot.com/place/15178887832583...           장안집   평가중
# 15  https://img.siksinhot.com/place/15320660911083...          장안복어   평가중
# 16  https://img.siksinhot.com/place/15157668164484...         장안바다향   평가중
# 17  https://img.siksinhot.com/place/15247941678023...           장안성   평가중
# 18  https://img.siksinhot.com/place/15320828052523...        장안평 국밥   평가중
# 19  https://img.siksinhot.com/place/15179768710806...          장안식당   평가중
#
#         location        menu
# 0             시청        돼지갈비
# 1   수원-팔달구/인계/행궁       치킨/통닭
# 2             함평       곱창/대창
# 3         기장군/정관   삼계탕/백숙/찜닭
# 4     왕십리/마장/답십리     경양식/돈가스
# 5            강릉시     회/횟집/참치
# 6         기장군/정관      장어/꼼장어
# 7     왕십리/마장/답십리  설렁탕/곰탕/갈비탕
# 8             시청   삼계탕/백숙/찜닭
# 9         기장군/정관    해물탕/해물요리
# 10            통영    해물탕/해물요리
# 11    왕십리/마장/답십리  해장국/국밥/육개장
# 12    왕십리/마장/답십리        한식주점
# 13    왕십리/마장/답십리      무국적 주점
# 14            임실  해장국/국밥/육개장
# 15            영천         한정식
# 16            속초         한정식
# 17      가좌/수색/응암          중식
# 18      북구-유동/신안  해장국/국밥/육개장
# 19            함평          중식
