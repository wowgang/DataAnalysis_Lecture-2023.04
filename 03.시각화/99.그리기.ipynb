# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
''' 
Tips 데이터
요일별 팁의 비율(bar)
인원수별 팁의 비율(bar)
'''

# %%
import seaborn as sns
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['tip_pct'] = (tips.tip / tips.total_bill *100).round(2)

# %%
# 요일별 팁의 비율
tipp = tips.pivot_table('tip_pct','day')
tipp
# Out:
#         tip_pct
# day
# Thur  16.126452
# Fri   16.991579
# Sat   15.314598
# Sun   16.689605

# %%
plt.figure(figsize=(5,3))
plt.bar(tipp.index, tipp.tip_pct)
plt.title('요일별 팁의 비율')
plt.show()

# %%
# 인원수별 팁의 비율
tipp2 = tips.pivot_table('tip_pct','size')
tipp2
# Out:
#         tip_pct
# size
# 1     21.727500
# 2     16.571410
# 3     15.214737
# 4     14.594865
# 5     14.152000
# 6     15.620000

# %%
plt.figure(figsize=(5,3))
plt.bar(tipp2.index, tipp2.tip_pct)
plt.title('인원수별 팁의 비율')
plt.show()

# %%
''' 
Anscombe 데이터
ans = sns.load_dataset('amscombe')
4개 Dataset에 대해 산포도+회귀식 그래프
'''

# %%
import seaborn as sns
ans = sns.load_dataset("anscombe")
ans.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
dataset_1 = ans[ans['dataset'] == 'I'] 
dataset_2 = ans[ans['dataset'] == 'II'] 
dataset_3 = ans[ans['dataset'] == 'III'] 
dataset_4 = ans[ans['dataset'] == 'IV']

# %%
plt.figure(figsize=(5,3))
plt.scatter(dataset_1['x'],dataset_1['y'], marker='o')
plt.title('anscombe dataset_I')
plt.show()

# %%
'''
y = 0.5x +3 직선의 방정식에서 선을 그릴떄 두개의 점을 찾아내야함
x가 4일때 y = 5
(4,5)
(14,10)
점 두개를 주면 플롯도 마찬가지로 선을 그을 수 있다
plt.plot(x,y)
'''

# %%
plt.figure(figsize=(5,3))
plt.scatter(dataset_1['x'],dataset_1['y'], marker='o') 
plt.plot([4,14],[5,10], 'r-', lw=2) # y = 0.5 * x + 3 회귀식이용 plot이 선......
plt.title('anscombe dataset_I')
plt.show()

# %%
for roman in ['I', 'II', 'III', 'IV']:
    ds = ans[ans.dataset == roman]
    plt.figure(figsize=(3,2))
    plt.scatter(ds.x,ds.y, marker='o') 
    plt.plot([3,20],[4.5,13], 'r-', lw=2) # y = 0.5 * x + 3 회귀식이용 plot이 선......
    plt.title(f'anscombe Dataset_{roman}')
    plt.show()

# %%
''' 
서울시 구별 cctv 개수 barh
기본순서
- index를 sort(오름)
- value를 sort(내림)
'''

# %%
cctv = pd.read_csv('../02.Pandas/data/cctv_pop.csv')
cctv.head()
# Out:
#     구별  CCTV갯수  최근 증가율     인구수     내국인    외국인    고령자  외국인비율  고령자비율
# 0  종로구    1980   46.23  153789  144683   9106  27818   5.92  18.09
# 1   중구    2584   53.54  131787  122499   9288  24392   7.05  18.51
# 2  용산구    2847   93.94  237285  222953  14332  39070   6.04  16.47

# %%
cctv['구별']
# Out:
# 0    종로구
# 1     중구
# 2    용산구
# Name: 구별, dtype: object

# %%
cctv['CCTV갯수']
# Out:
# 0    1980
# 1    2584
# 2    2847
# Name: CCTV갯수, dtype: int64

# %%
plt.figure(figsize=(4,2))
plt.barh(cctv['구별'], cctv['CCTV갯수'])
plt.title('서울시 구별 cctv 개수 barh')
plt.show()

# %%
cctv2 = pd.read_csv('../02.Pandas/data/cctv_pop1.csv')
cctv2.head()
# Out:
#     구별  CCTV갯수  최근 증가율     인구수     내국인    외국인    고령자  외국인비율  고령자비율
# 0  종로구    1980   46.23  153789  144683   9106  27818   5.92  18.09
# 1   중구    2584   53.54  131787  122499   9288  24392   7.05  18.51
# 2  용산구    2847   93.94  237285  222953  14332  39070   6.04  16.47
# 3  성동구    4047   36.58  292672  285990   6682  46380   2.28  15.85
# 4  광진구    3480   46.53  352627  339996  12631  51723   3.58  14.67

# %%
plt.barh(cctv2['구별'], cctv2['CCTV갯수'])
plt.title('서울시 구별 cctv 개수 barh')
plt.show()

# %%
cctv2 = cctv2[['구별','CCTV갯수']]
cctv2
# Out:
#       구별  CCTV갯수
# 0    종로구    1980
# 1     중구    2584
# 2    용산구    2847
# 3    성동구    4047
# 4    광진구    3480
# 5   동대문구    2759
# 6    중랑구    4193
# 7    성북구    4842
# 8    강북구    3321
# 9    도봉구    2247
# 10   노원구    2617
# 11   은평구    4653
# 12  서대문구    3445
# 13   마포구    2628
# 14   양천구    3851
# 15   강서구    3265
# 16   구로구    4693
# 17   금천구    2636
# 18  영등포구    4553
# 19   동작구    2671
# 20   관악구    5398
# 21   서초구    4995
# 22   강남구    7243
# 23   송파구    3203
# 24   강동구    3190

# %%
cctv2.columns
# Out:
# Index(['구별', 'CCTV갯수'], dtype='object')

# %%
cctv2.drop([0], inplace=True)
cctv2.set_index('구별', inplace=True)
cctv2.head(3)
# Out:
#      CCTV갯수
# 구별
# 중구     2584
# 용산구    2847
# 성동구    4047

# %%
# 1. Unsorted
plt.barh(cctv2.index, cctv2.CCTV갯수)
plt.title('자치구별 CCTV 설치대수')
plt.show()

# %%
si = cctv2.CCTV갯수.sort_index(ascending=False)
si.head()
# Out:
# 구별
# 중랑구     4193
# 중구      2584
# 은평구     4653
# 용산구     2847
# 영등포구    4553
# Name: CCTV갯수, dtype: int64

# %%
cctv2.index
# Out:
# Index(['중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구', '도봉구', '노원구',
#        '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구', '영등포구', '동작구', '관악구',
#        '서초구', '강남구', '송파구', '강동구'],
#       dtype='object', name='구별')

# %%
# index로 정렬
si = cctv2.CCTV갯수.sort_index(ascending=False)
plt.barh(si.index, si.values)  # 시리즈가돼서 index랑 values로 적어준다
plt.title('자치구별 CCTV 설치대수(자치구명으로 정렬)')
plt.show()

# %%
# 3. 설치대수로 정렬
sv = cctv2.CCTV갯수.sort_values()
plt.barh(sv.index, sv.values)
plt.title('자치구별 CCTV 설치대수(설치대수로 정렬)')
plt.show()

# %%
''' 
Titanic
- embark_town, sex => 생존율
- 나이 => displot 분산 그래프
'''

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class
# 0         0       3    male  22.0      1      0   7.2500        S  Third  \
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
s = titanic.pivot_table('survived', 'embark_town','sex')*100
s.head()
# Out:
# sex             female       male
# embark_town
# Cherbourg    87.671233  30.526316
# Queenstown   75.000000   7.317073
# Southampton  68.965517  17.460317

# %%
# 선생님 답
sns.heatmap(s, annot=True, fmt='.2f'); # 소수점 둘째자리까지

# %%
# 결측치를
sns.displot(x='age', data=titanic, kde=True);

# %%
# 결측치를 평균으로 변경
titanic.age.fillna(titanic.age.mean(), inplace=True) # 이걸하면 아래 그래프의 평균이 지나치게 높아지는 그림이 됨
sns.displot(x='age', data=titanic, kde=True);
